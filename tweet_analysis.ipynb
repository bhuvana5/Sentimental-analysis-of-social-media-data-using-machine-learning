# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(r"C:/Users/student/Documents/dataset/Tweets.csv")

# %%
data['tweet_id'].count()
# Out:
# 14640

# %%
data['retweet_count'].value_counts()
# Out:
# 0     13873
# 1       640
# 2        66
# 3        22
# 4        17
# 5         5
# 7         3
# 6         3
# 22        2
# 8         1
# 32        1
# 9         1
# 31        1
# 18        1
# 15        1
# 28        1
# 44        1
# 11        1
# Name: retweet_count, dtype: int64

# %%
data['tweet_location'].count()
# Out:
# 9907

# %%
data[data['tweet_location']=='Los Angeles']
# Out:
#            tweet_id airline_sentiment  airline_sentiment_confidence  \
# 7      5.703000e+17           neutral                        0.6340
# 9      5.702950e+17          positive                        1.0000
# 22     5.702590e+17          positive                        1.0000
# 42     5.700160e+17           neutral                        1.0000
# 45     5.700120e+17          positive                        1.0000
# 71     5.699500e+17           neutral                        0.6492
# 73     5.699460e+17          negative                        1.0000
# 82     5.699330e+17          negative                        0.6792
# 146    5.696080e+17          negative                        0.6790
# 163    5.695410e+17          negative                        0.6517
# 274    5.689020e+17          negative                        1.0000
# 300    5.688280e+17           neutral                        1.0000
# 551    5.702840e+17           neutral                        0.6630
# ...

# %%
data['tweet_location'].value_counts()
# Out:
# Boston, MA                        157
# New York, NY                      156
# Washington, DC                    150
# New York                          127
# USA                               126
# Chicago                           104
# Los Angeles, CA                    96
# New York City                      96
# NYC                                95
# San Francisco, CA                  91
# San Francisco                      86
# Chicago, IL                        81
# Brooklyn, NY                       66
# Austin, TX                         64
# Los Angeles                        64
# Washington, D.C.                   63
# Boston                             62
# Dallas, TX                         54
# Washington DC                      53
# Nashville, TN                      45
# NY                                 42
# Texas                              42
# Philadelphia, PA                   38
# San Diego                          38
# Denver, CO                         37
# ...

# %%
a=data[data['airline_sentiment']=='positive'].count()
a
# Out:
# tweet_id                        2363
# airline_sentiment               2363
# airline_sentiment_confidence    2363
# negativereason                     0
# negativereason_confidence        330
# airline                         2363
# airline_sentiment_gold             5
# name                            2363
# negativereason_gold                0
# retweet_count                   2363
# text                            2363
# tweet_coord                      175
# tweet_created                   2363
# tweet_location                  1734
# user_timezone                   1684
# dtype: int64

# %%
data[data['name']=='jnardino'].count()
# Out:
# tweet_id                        4
# airline_sentiment               4
# airline_sentiment_confidence    4
# negativereason                  3
# negativereason_confidence       4
# airline                         4
# airline_sentiment_gold          0
# name                            4
# negativereason_gold             0
# retweet_count                   4
# text                            4
# tweet_coord                     0
# tweet_created                   4
# tweet_location                  0
# user_timezone                   4
# dtype: int64

# %%
data.groupby('user_timezone')['tweet_created'].count()
# Out:
# user_timezone
# Abu Dhabi                        23
# Adelaide                          7
# Alaska                          108
# America/Atikokan                  1
# America/Boise                     3
# America/Chicago                  37
# America/Detroit                   1
# America/Los_Angeles              15
# America/New_York                 26
# Amsterdam                        74
# Arizona                         229
# Athens                           16
# Atlantic Time (Canada)          497
# Bangkok                           4
# Beijing                          11
# Berlin                            9
# Bern                              1
# Bogota                            5
# Brasilia                         23
# Brisbane                         10
# Brussels                          9
# Bucharest                         1
# Buenos Aires                     14
# Canberra                          1
# Caracas                           9
# ...
